# %% [markdown]
# # Resource Page

# %% [markdown]
# > 1. https://www.khanacademy.org/computing/computer-science/algorithms/binary-search/a/binary-search
#
#
#
# ![image.png](attachment:image.png)
#
#
#
# ![image.png](attachment:image-2.png)
#
#
#
# ![image.png](attachment:image-3.png)
#
#
#
# > 2. https://www.youtube.com/watch?v=iDbdXTMnOmE
#
#
#
# ![image.png](attachment:image-4.png)
#
#
#
# > 3. GeeksforGeeks Binary Search Tutorial: https://www.geeksforgeeks.org/binary-search/
#
# > 4. Khan Academy Binary Search Lesson: https://www.khanacademy.org/computing/computer-science/algorithms/binary-search/a/binary-search
#
# > 5. Coursera Algorithms, Part I Course: https://www.coursera.org/learn/algorithms-part1
#
# > 6. LeetCode: https://leetcode.com/problemset/all/?topicSlugs=binary-search
#
# >7. CS Dojo Binary Search Tutorial: https://www.youtube.com/watch?v=P3YID7liBug
#
# > 8. Tushar Roy Binary Search Tutorial: https://www.youtube.com/watch?v=GU7DpgHINWQ
