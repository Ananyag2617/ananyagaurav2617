# %% [markdown]
# # Bash Tutorial
# > A brief overview of Bash, on your way to becoming a Linux expert.  When a computer boots up, a kernel (MacOS, Windows, Linux) is started.  This kernel provides a shell that allows user to interact with a most basic set of commands.  Typically, the casual user will not interact with the shell as a Desktop User Interface is started by the computer boot up process.  To activate the shell directly, users will run a "terminal" through the Desktop, VS Code or activate "console" while on a cloud computer like AWS.
#
# - toc: true
# - comments: true
# - permalink: /techtalk/bash
# - image: /images/bash.jpeg
# - categories: [techtalk]

# %% [markdown]
# ## Prerequisites for Bash on Jupyter
# > Being able to find a Bash Reference.  Here is a [Bash Cheat Sheet](https://www.pcwdld.com/bash-cheat-sheet)
#
# > Install the Bash Kernel for Jupyter notebooks.  Expectations are pip3 and python3 are defined within the path.  The bash shell allowed construction of this tutorial.
#
# - pip install bash_kernel
# - python -m bash_kernel.install
#
# Selecting a kernel in "code --project--" or "jupyter notebook --file.ipynb--" that have bash in options.
# ![](images/kernels.png)

# %% [markdown]
# ## Prerequisites for Project Directory
# > Practice pulling code from git to your machine. This will create a project directory and add APCSP github project to the directory.  There is conditional logic to make sure that directory and pull only happen if it does not (!) exist.
#
# - Hack: Change variables, make new directory, clone to that directory.

# %%
echo "Using conditional statement to create a project directory and project"

# Variable section
export project_dir=$HOME/vscode  # change vscode to different name to test git clone
export project=$project_dir/APCSP  # change APCSP to name of project from git clone
export project_repo="https://github.com/nighthawkcoders/APCSP.git"  # change to project of choice

cd ~    # start in home directory

# Conditional block to make a project directory
if [ ! -d $project_dir ]
then 
    echo "Directory $project_dir does not exists... makinng directory $project_dir"
    mkdir -p $project_dir
fi
echo "Directory $project_dir exists." 

# Conditional block to git clone a project from project_repo
if [ ! -d $project ]
then
    echo "Directory $project does not exists... cloning $project_repo"
    cd $project_dir
    git clone $project_repo
    cd ~
fi
echo "Directory $project exists."
# Out:
# Using conditional statement to create a project directory and project
# Directory /home/ananyag2617/vscode exists.
# Directory /home/ananyag2617/vscode/APCSP exists.

# %% [markdown]
# ### Look inside Fastpages/Github page project
# > All computers contain files and directories.  The clone brought more files from cloud to your machine.  Using the bash shell you will see some commands that show and interact with files and directories.
#
# - "ls" lists computer files in Unix and Unix-like operating systems
# - "cd" offers way to navigate and change working directory
# - "pwd" print working directory
# - "echo" used to display line of text/string that are passed as an argument

# %%
# You must run cells above to define variable and project

echo "Navigate to project, then navigate to area wwhere files were cloned"
cd $project
pwd

echo ""
echo "list top level or root of files with project pulled from github"
ls

echo ""
echo "list again with hidden files pulled from github"
ls -a   # hidden files flag, many shell commands have flags

echo ""
echo "list all files in long format"
ls -al   # all files and long listing
# Out:
# Navigate to project, then navigate to area wwhere files were cloned
# /home/ananyag2617/vscode/APCSP
#
# list top level or root of files with project pulled from github
# Gemfile    _action_files    _layouts    _posts  docker-compose.yml
# LICENSE    _config.yml      _notebooks  _sass   images
# Makefile   _fastpages_docs  _pages      _word   index.html
# README.md  _includes        _plugins    assets  python
#
# list again with hidden files pulled from github
# .                   .gitignore  _action_files    _pages    docker-compose.yml
# ..                  .vscode     _config.yml      _plugins  images
# .devcontainer.json  Gemfile     _fastpages_docs  _posts    index.html
# .git                LICENSE     _includes        _sass     python
# .gitattributes      Makefile    _layouts         _word
# .github             README.md   _notebooks       assets
#
# list all files in long format
# total 120
# drwxr-xr-x 18 ananyag2617 ananyag2617  4096 Aug 21 20:52 .
# drwxr-xr-x  4 ananyag2617 ananyag2617  4096 Aug 25 15:53 ..
# -rw-r--r--  1 ananyag2617 ananyag2617   420 Aug 21 20:52 .devcontainer.json
# drwxr-xr-x  8 ananyag2617 ananyag2617  4096 Aug 25 15:00 .git
# -rw-r--r--  1 ananyag2617 ananyag2617    84 Aug 21 20:52 .gitattributes
# drwxr-xr-x  4 ananyag2617 ananyag2617  4096 Aug 21 20:52 .github
# -rw-r--r--  1 ananyag2617 ananyag2617   917 Aug 21 20:52 .gitignore
# drwxr-xr-x  2 ananyag2617 ananyag2617  4096 Aug 21 20:52 .vscode
# -rwxr-xr-x  1 ananyag2617 ananyag2617  1304 Aug 21 20:52 Gemfile
# -rw-r--r--  1 ananyag2617 ananyag2617 11351 Aug 21 20:52 LICENSE
# -rwxr-xr-x  1 ananyag2617 ananyag2617  1422 Aug 21 20:52 Makefile
# -rwxr-xr-x  1 ananyag2617 ananyag2617  3614 Aug 21 20:52 README.md
# drwxr-xr-x  2 ananyag2617 ananyag2617  4096 Aug 21 20:52 _action_files
# -rw-r--r--  1 ananyag2617 ananyag2617  3716 Aug 21 20:52 _config.yml
# drwxr-xr-x  2 ananyag2617 ananyag2617  4096 Aug 21 20:52 _fastpages_docs
# drwxr-xr-x  2 ananyag2617 ananyag2617  4096 Aug 21 20:52 _includes
# drwxr-xr-x  2 ananyag2617 ananyag2617  4096 Aug 21 20:52 _layouts
# drwxr-xr-x  3 ananyag2617 ananyag2617  4096 Aug 25 14:59 _notebooks
# drwxr-xr-x  2 ananyag2617 ananyag2617  4096 Aug 25 14:59 _pages
# drwxr-xr-x  2 ananyag2617 ananyag2617  4096 Aug 21 20:52 _plugins
# drwxr-xr-x  2 ananyag2617 ananyag2617  4096 Aug 25 14:59 _posts
# drwxr-xr-x  3 ananyag2617 ananyag2617  4096 Aug 21 20:52 _sass
# drwxr-xr-x  2 ananyag2617 ananyag2617  4096 Aug 21 20:52 _word
# drwxr-xr-x  4 ananyag2617 ananyag2617  4096 Aug 21 20:52 assets
# -rwxr-xr-x  1 ananyag2617 ananyag2617  1136 Aug 21 20:52 docker-compose.yml
# drwxr-xr-x  5 ananyag2617 ananyag2617  4096 Aug 21 20:52 images
# -rw-r--r--  1 ananyag2617 ananyag2617  1061 Aug 21 20:52 index.html
# drwxr-xr-x  2 ananyag2617 ananyag2617  4096 Aug 21 20:52 python

# %%
# You must run cells above to define variable and project

echo "Look for posts"
export posts=$project/_posts  # _posts inside project
cd $posts  # this should exist per fastpages
pwd  # present working directory
ls -l  # list posts
# Out:
# Look for posts
# /home/ananyag2617/vscode/APCSP/_posts
# total 228
# -rw-r--r-- 1 ananyag2617 ananyag2617 21306 Aug 21 20:52 2022-06-01-TT160-deploy.md
# -rw-r--r-- 1 ananyag2617 ananyag2617  5861 Aug 21 20:52 2022-07-07-PBL-binary.md
# -rw-r--r-- 1 ananyag2617 ananyag2617  3085 Aug 21 20:52 2022-07-08-PBL-grade_calc.md
# -rw-r--r-- 1 ananyag2617 ananyag2617  3698 Aug 21 20:52 2022-07-08-PBL-graph.md
# -rw-r--r-- 1 ananyag2617 ananyag2617  5729 Aug 21 20:52 2022-07-08-PBL-life.md
# -rw-r--r-- 1 ananyag2617 ananyag2617 14387 Aug 21 20:52 2022-07-08-PBL-snake.md
# -rw-r--r-- 1 ananyag2617 ananyag2617   334 Aug 21 20:52 2022-07-10-PBL-database.md
# -rw-r--r-- 1 ananyag2617 ananyag2617  2908 Aug 21 20:52 2022-07-10-PBL-jokes.md
# -rw-r--r-- 1 ananyag2617 ananyag2617  4046 Aug 21 20:52 2022-07-10-PBL-rapidapi.md
# -rw-r--r-- 1 ananyag2617 ananyag2617  6685 Aug 21 20:52 2022-07-19-PBL-calculator.md
# -rw-r--r-- 1 ananyag2617 ananyag2617 23325 Aug 21 20:52 2022-07-25-CSP-workshop.md
# -rw-r--r-- 1 ananyag2617 ananyag2617  2333 Aug 21 20:52 2022-08-15-TP000-student_score_history.md
# -rw-r--r-- 1 ananyag2617 ananyag2617  4363 Aug 21 20:52 2022-08-15-TP100-pseudo_code.md
# -rw-r--r-- 1 ananyag2617 ananyag2617  7968 Aug 21 20:52 2022-08-15-TR100-tool_setup.md
# -rw-r--r-- 1 ananyag2617 ananyag2617 15026 Aug 21 20:52 2022-08-15-TT100-tools.md
# -rw-r--r-- 1 ananyag2617 ananyag2617  5590 Aug 21 20:52 2022-08-15-TT101-vscode-wsl.md
# -rw-r--r-- 1 ananyag2617 ananyag2617  2155 Aug 25 14:59 2022-08-22-TR110-intro_python.md
# -rw-r--r-- 1 ananyag2617 ananyag2617  5173 Aug 21 20:52 2022-08-22-TT110-fastpages.md
# -rw-r--r-- 1 ananyag2617 ananyag2617  2798 Aug 25 14:59 2022-08-22-TT110-focus.md
# -rw-r--r-- 1 ananyag2617 ananyag2617  2737 Aug 21 20:52 2022-08-29-TR120-data_abstract.md
# -rw-r--r-- 1 ananyag2617 ananyag2617 10683 Aug 21 20:52 2022-08-29-TT120-agile.md
# -rw-r--r-- 1 ananyag2617 ananyag2617  4498 Aug 21 20:52 2022-08-29-TT120-html_fragments.md
# -rw-r--r-- 1 ananyag2617 ananyag2617  9037 Aug 21 20:52 2022-09-05-TP130-create_performance_task.md
# -rw-r--r-- 1 ananyag2617 ananyag2617  7753 Aug 21 20:52 2022-09-05-TP131-create-task-bria.md
# -rw-r--r-- 1 ananyag2617 ananyag2617  8066 Aug 21 20:52 2022-09-05-TR130-creative_development.md
# -rw-r--r-- 1 ananyag2617 ananyag2617  3520 Aug 21 20:52 2022-09-05-TT130-applab.md
# -rw-r--r-- 1 ananyag2617 ananyag2617   720 Aug 21 20:52 README.md

# %%
# You must run cells above to define variable and project

echo "Look for notebooks"
export notebooks=$project/_notebooks  # _notebooks is inside project
cd $notebooks   # this should exist per fastpages
pwd  # present working directory
ls -l  # list notebooks
# Out:
# Look for notebooks
# /home/ananyag2617/vscode/APCSP/_notebooks
# total 144
# -rw-r--r-- 1 ananyag2617 ananyag2617 14243 Aug 21 20:52 2022-06-01-TT150-webapi_tutorial.ipynb
# -rw-r--r-- 1 ananyag2617 ananyag2617  8653 Aug 21 20:52 2022-07-21-PBL-neo4j_intro.ipynb
# -rw-r--r-- 1 ananyag2617 ananyag2617 11694 Aug 25 14:59 2022-08-22-TP110-python_hello.ipynb
# -rw-r--r-- 1 ananyag2617 ananyag2617 20003 Aug 25 14:59 2022-08-22-TT110-anthony_and_sahil.ipynb
# -rw-r--r-- 1 ananyag2617 ananyag2617  9525 Aug 25 14:59 2022-08-22-TT110-bash_tutorial.ipynb
# -rw-r--r-- 1 ananyag2617 ananyag2617 35721 Aug 25 14:59 2022-08-25-tool_check.ipynb
# -rw-r--r-- 1 ananyag2617 ananyag2617 10141 Aug 21 20:52 2022-08-29-TP120-python_lists.ipynb
# -rw-r--r-- 1 ananyag2617 ananyag2617 12632 Aug 21 20:52 2022-09-05-TT130-js_tutorial.ipynb
# -rw-r--r-- 1 ananyag2617 ananyag2617   771 Aug 21 20:52 README.md
# drwxr-xr-x 2 ananyag2617 ananyag2617  4096 Aug 21 20:52 images

# %%
# You must run cells above to define notebooks location

echo "Look for images in notebooks, print working directory, list files"
cd $notebooks/images  # this should exist per fastpages
pwd
ls -l
# Out:
# Look for images in notebooks, print working directory, list files
# /home/ananyag2617/vscode/APCSP/_notebooks/images
# total 100
# -rw-r--r-- 1 ananyag2617 ananyag2617 101617 Aug 21 20:52 kernels.png

# %% [markdown]
# ### Look inside a Markdown File
# > "cat" reads data from the file and gives its content as output

# %%
# You must run cells above to define project
echo "Navigate to project, then navigate to area wwhere files were cloned"

cd $project
echo "show the contents of README.md"
echo ""

cat README.md  # show contents of file, in this case markdown
echo ""
echo "end of README.md"
# Out:
# Navigate to project, then navigate to area wwhere files were cloned
# show the contents of README.md
#
# [//]: # (This template replaces README.md when someone creates a new repo with the fastpages template.)
#
# ![](https://github.com/nighthawkcoders/APCSP/workflows/CI/badge.svg)
# ![](https://github.com/nighthawkcoders/APCSP/workflows/GH-Pages%20Status/badge.svg)
# [![](https://img.shields.io/static/v1?label=fastai&message=fastpages&color=57aeac&labelColor=black&style=flat&logo=data:image/png;base64,...)](https://github.com/fastai/fastpages)
#
# https://nighthawkcoders.github.io/APCSP/
#
# # My Blog
#
#
# _powered by [fastpages](https://github.com/fastai/fastpages)_
#
#
# ## What To Do Next?
#
# Great!  You have setup your repo.  Now its time to start writing content.  Some helpful links:
#
# - [Writing Blogs With Jupyter](https://github.com/fastai/fastpages#writing-blog-posts-with-jupyter)
#
# - [Writing Blogs With Markdown](https://github.com/fastai/fastpages#writing-blog-posts-with-markdown)
#
# - [Writing Blog Posts With Word](https://github.com/fastai/fastpages#writing-blog-posts-with-microsoft-word)
#
# - [(Optional) Preview Your Blog Locally](_fastpages_docs/DEVELOPMENT.md)
#
# Note: you may want to remove example blog posts from the `_posts`,  `_notebooks` or `_word` folders (but leave them empty, don't delete these folders) if you don't want these blog posts to appear on your site.
#
# Please use the [nbdev & blogging channel](https://forums.fast.ai/c/fastai-users/nbdev/48) in the fastai forums for any questions or feature requests.
#
# end of README.md

# %% [markdown]
# ### Env, Git and GitHub
# > Env(ironment) is used to capture things like path to Code or Home directory.  Git and GitHub is NOT Only used to exchange code between individuals, it is often used to exchange code through servers, in our case deployment for Website.   All tools we use have a behind the scenes hav relationship with the system they run on (MacOS, Windows, Linus) or a relationship with servers which they are connected to (ie GitHub).  There is an "env" command in bash.  There are environment files and setting files (.git/config) for Git.  They both use a key/value concept.
#
# - "env" show setting for your shell
# - "git clone" sets up a director of files
# - "cd $project" allows user to move inside that directory of files
# - ".git" is a hidden directory that is used by git to establish relationship between machine and the git server on GitHub.

# %%
# This command has no dependencies

echo "Show the shell environment variables, key on left of equal value on right"
echo ""

env
# Out:
# Show the shell environment variables, key on left of equal value on right
#
# SHELL=/bin/bash
# PYTHONUNBUFFERED=1
# project=/home/ananyag2617/vscode/APCSP
# WSL_DISTRO_NAME=Ubuntu
# ELECTRON_RUN_AS_NODE=1
# VSCODE_AMD_ENTRYPOINT=vs/workbench/api/node/extensionHostProcess
# NAME=Code
# PWD=/home/ananyag2617/vscode/APCSP
# LOGNAME=ananyag2617
# project_dir=/home/ananyag2617/vscode
# HOME=/home/ananyag2617
# LANG=C.UTF-8
# WSL_INTEROP=/run/WSL/1324_interop
# LS_COLORS=rs=0:di=01;34:ln=01;36:mh=00:pi=40;33:so=01;35:do=01;35:bd=40;33;01:cd=40;33;01:or=40;31;01:mi=00:su=37;41:sg=30;43:ca=30;41:tw=30;42:ow=34;42:st=37;44:ex=01;32:*.tar=01;31:*.tgz=01;31:*.arc=01;31:*.arj=01;31:*.taz=01;31:*.lha=01;31:*.lz4=01;31:*.lzh=01;31:*.lzma=01;31:*.tlz=01;31:*.txz=01;31:*.tzo=01;31:*.t7z=01;31:*.zip=01;31:*.z=01;31:*.dz=01;31:*.gz=01;31:*.lrz=01;31:*.lz=01;31:*.lzo=01;31:*.xz=01;31:*.zst=01;31:*.tzst=01;31:*.bz2=01;31:*.bz=01;31:*.tbz=01;31:*.tbz2=01;31:*.tz=01;31:*.deb=01;31:*.rpm=01;31:*.jar=01;31:*.war=01;31:*.ear=01;31:*.sar=01;31:*.rar=01;31:*.alz=01;31:*.ace=01;31:*.zoo=01;31:*.cpio=01;31:*.7z=01;31:*.rz=01;31:*.cab=01;31:*.wim=01;31:*.swm=01;31:*.dwm=01;31:*.esd=01;31:*.jpg=01;35:*.jpeg=01;35:*.mjpg=01;35:*.mjpeg=01;35:*.gif=01;35:*.bmp=01;35:*.pbm=01;35:*.pgm=01;35:*.ppm=01;35:*.tga=01;35:*.xbm=01;35:*.xpm=01;35:*.tif=01;35:*.tiff=01;35:*.png=01;35:*.svg=01;35:*.svgz=01;35:*.mng=01;35:*.pcx=01;35:*.mov=01;35:*.mpg=01;35:*.mpeg=01;35:*.m2v=01;35:*.mkv=01;35:*.webm=01;35:*.ogm=01;35:*.mp4=01;35:*.m4v=01;35:*.mp4v=01;35:*.vob=01;35:*.qt=01;35:*.nuv=01;35:*.wmv=01;35:*.asf=01;35:*.rm=01;35:*.rmvb=01;35:*.flc=01;35:*.avi=01;35:*.fli=01;35:*.flv=01;35:*.gl=01;35:*.dl=01;35:*.xcf=01;35:*.xwd=01;35:*.yuv=01;35:*.cgm=01;35:*.emf=01;35:*.ogv=01;35:*.ogx=01;35:*.aac=00;36:*.au=00;36:*.flac=00;36:*.m4a=00;36:*.mid=00;36:*.midi=00;36:*.mka=00;36:*.mp3=00;36:*.mpc=00;36:*.ogg=00;36:*.ra=00;36:*.wav=00;36:*.oga=00;36:*.opus=00;36:*.spx=00;36:*.xspf=00;36:
# WAYLAND_DISPLAY=wayland-0
# posts=/home/ananyag2617/vscode/APCSP/_posts
# LESSCLOSE=/usr/bin/lesspipe %s %s
# VSCODE_HANDLES_SIGPIPE=true
# TERM=xterm-256color
# LESSOPEN=| /usr/bin/lesspipe %s
# USER=ananyag2617
# PYTHONIOENCODING=utf-8
# notebooks=/home/ananyag2617/vscode/APCSP/_notebooks
# DISPLAY=:0
# SHLVL=2
# PAGER=cat
# project_repo=https://github.com/nighthawkcoders/APCSP.git
# VSCODE_CWD=/mnt/c/Users/ANANYA GAURAV/AppData/Local/Programs/Microsoft VS Code
# XDG_RUNTIME_DIR=/mnt/wslg/runtime-dir
# PS1=[PEXP\[\]ECT_PROMPT>
# WSLENV=ELECTRON_RUN_AS_NODE/w:
# VSCODE_WSL_EXT_LOCATION=/mnt/c/Users/ANANYA GAURAV/.vscode/extensions/ms-vscode-remote.remote-wsl-0.66.3
# XDG_DATA_DIRS=/usr/local/share:/usr/share:/var/lib/snapd/desktop
# PATH=/home/ananyag2617/.vscode-server/bin/e4503b30fc78200f846c62cf8091b76ff5547662/bin/remote-cli:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/usr/lib/wsl/lib:/mnt/c/windows/system32:/mnt/c/windows:/mnt/c/windows/System32/Wbem:/mnt/c/windows/System32/WindowsPowerShell/v1.0/:/mnt/c/windows/System32/OpenSSH/:/mnt/c/Program Files/Git/cmd:/mnt/c/Users/ANANYA GAURAV/AppData/Local/Microsoft/WindowsApps:/mnt/c/Users/ANANYA GAURAV/AppData/Local/Programs/Microsoft VS Code/bin:/snap/bin
# VSCODE_NLS_CONFIG={"locale":"en","availableLanguages":{}}
# HOSTTYPE=x86_64
# PULSE_SERVER=/mnt/wslg/PulseServer
# VSCODE_HANDLES_UNCAUGHT_ERRORS=true
# OLDPWD=/home/ananyag2617/vscode/APCSP/_notebooks/images
# VSCODE_IPC_HOOK_CLI=/mnt/wslg/runtime-dir/vscode-ipc-bd47b5d6-4276-4550-9584-b0f86c72e0c5.sock
# _=/usr/bin/env

# %%
# This command has dependencies on project

cd $project

echo ""
echo "show the secrets of .git"
cd .git
ls -l

echo ""
echo "look at config file"
cat config
# Out:
# show the secrets of .git
# total 68
# -rw-r--r--  1 ananyag2617 ananyag2617   353 Aug 25 15:21 FETCH_HEAD
# -rw-r--r--  1 ananyag2617 ananyag2617    23 Aug 21 20:52 HEAD
# -rw-r--r--  1 ananyag2617 ananyag2617    41 Aug 25 15:00 ORIG_HEAD
# drwxr-xr-x  2 ananyag2617 ananyag2617  4096 Aug 21 20:51 branches
# -rw-r--r--  1 ananyag2617 ananyag2617   270 Aug 25 14:55 config
# -rw-r--r--  1 ananyag2617 ananyag2617    73 Aug 21 20:51 description
# drwxr-xr-x  2 ananyag2617 ananyag2617  4096 Aug 25 14:45 hooks
# -rw-r--r--  1 ananyag2617 ananyag2617 20021 Aug 25 14:59 index
# drwxr-xr-x  2 ananyag2617 ananyag2617  4096 Aug 21 20:51 info
# drwxr-xr-x  3 ananyag2617 ananyag2617  4096 Aug 21 20:52 logs
# drwxr-xr-x 50 ananyag2617 ananyag2617  4096 Aug 25 14:59 objects
# -rw-r--r--  1 ananyag2617 ananyag2617   271 Aug 21 20:52 packed-refs
# drwxr-xr-x  5 ananyag2617 ananyag2617  4096 Aug 21 20:52 refs
#
# look at config file
# [core]
# 	repositoryformatversion = 0
# 	filemode = false
# 	bare = false
# 	logallrefupdates = true
# [remote "origin"]
# 	url = https://github.com/nighthawkcoders/APCSP.git
# 	fetch = +refs/heads/*:refs/remotes/origin/*
# [branch "master"]
# 	remote = origin
# 	merge = refs/heads/master

# %% [markdown]
# ## Hacks
# > Go back to some of the deployment procedures and think about some thing you could verify through Bash notebook.
#
# - Is there anything we use to verify tools we install? Think about versions.
# - Is there anything we could verify with Anaconda?
# - How would you update a repository?
# - Really cool would be automating a procedure from installation.
