# %% [markdown]
# # Tri 2 Final Corrections!

# %% [markdown]
# # Reflection
# After taking the test I think I could have done a lot better. I realized that I rushed a little when taking it and didnt consider all the answer choices when answering. Additionally after answering each question I did check online and changed some answers because of that, so for next time I will make sure to double check before changing my answers. I feel like if I had spent a little more time doing the test, I would have scored better. In terms of the questions that include code, I understood what the code meant, but was confused about what the output would exactly look like.
# # How I will improve
# To improve I will watch more collegeboeard videos on the topics I got wrong, I will try to spend more time on each question and not rush, and I will also make sure to double check before changing my answers

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Question 5
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
