# %% [markdown]
# # 2020 MC

# %% [markdown]
# # Questions asked during the test
# - what is a “citizen science” approach?
# - What is Creative Commons?

# %% [markdown]
# # My mistakes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The reason I got this wrong because the loop begins at the end of the list and moves to the start of the list, so index should be decremented, not incremented. In addition, the decrement should be inserted between lines 7 and 8 to ensure that all elements are checked.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# I didnt choose two answers

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The two line graphs are roughly the same shape, indicating that the average amount of data stored per user remained about the same across all eight years.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
#  For these values, the procedure repeatedly adds -2 to result five times, resulting in the intended product -10.

# %% [markdown]
# # What is a “citizen science” approach?
# Citizen science is the practice of public participation and collaboration in scientific research to increase scientific knowledge. Through citizen science, people share and contribute to data monitoring and collection programs.

# %% [markdown]
# # What is Creative Commons?
# Creative Commons licenses give everyone from individual creators to large institutions a standardized way to grant the public permission to use their creative work under copyright law.
